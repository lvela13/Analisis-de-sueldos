# %% [markdown]
# # Análisis de sueldos con Python

# %% [markdown]
# ## Data
#
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Argentina
# ](https://docs.google.com/spreadsheets/d/1-ZRznwS4TK74o90aOiCKS5SiXxUQ2buN1wxZIMHQmzQ/edit#gid=557755710)
# * [2021.2 - sysarmy - Encuesta de remuneración salarial Latam
# ](https://docs.google.com/spreadsheets/d/1BkBNt1MHVS7DeIlpgmK9l6krtSQ5t_olRhlcyxMeKy0/edit#gid=557755710)

# %% [markdown]
# 1. Descargar, leer y unir en una sola estructura de datos. ¿Qué estructura elegiste y por qué?

# %%
#Primero hice una copia de los archivos originales, luego de reemplazar las "," por "|" y los descargué en csv con el texto "Sin comas" adelante

path_to_file_1 = "Sin comas 2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv"
path_to_file_2 = "Sin comas 2021.2 - sysarmy - Encuesta de remuneración salarial Latam - Latam.csv"

raw_cases_ARG = []
raw_cases_LATAM = []
dic_cases_list_ARG = []
dic_cases_list_LATAM = []
dic_cases_list_ALL = []

#elegi trabajar con una lista de diccionarios

# %%
with open(f"{path_to_file_1}", "r") as f_ARG:
    for line in iter(f_ARG.readline, ""):
        raw_cases_ARG.append(line.split(","))

# %%
with open(f"{path_to_file_2}", "r") as f_LATAM:
    for line in iter(f_LATAM.readline, ""):
        raw_cases_LATAM.append(line.split(","))

# %%
del raw_cases_ARG[:10]
del raw_cases_LATAM[:11]

# %%
keys_dic = raw_cases_ARG[9] #solo para ver el index 

for i,c in enumerate (keys_dic):
    print (i,c)
# Out:
# 0 Dónde estás trabajando
# 1 Tipo de contrato
# 2 Salario mensual o retiro BRUTO (en tu moneda local)
# 3 Salario mensual o retiro NETO (en tu moneda local)
# 4 Pagos en dólares
# 5 ¿Cuál fue el último valor de dólar que tomaron?
# 6 ¿Qué tan conforme estás con tu sueldo?
# 7 Cómo creés que está tu sueldo con respecto al último semestre
# 8 Recibís algún tipo de bono
# 9 A qué está atado el bono
# 10 ¿Tuviste ajustes por inflación durante 2021?
# 11 ¿De qué % fue el ajuste total?
# 12 ¿En qué mes fue el último ajuste?
# 13 Trabajo de
# 14 Años de experiencia
# 15 Años en la empresa actual
# 16 Años en el puesto actual
# 17 ¿Gente a cargo?
# 18 Plataformas
# 19 Lenguajes de programación o tecnologías.
# 20 Frameworks| herramientas y librerías
# 21 Bases de datos
# 22 QA / Testing
# 23 IDEs
# 24 Cantidad de personas en tu organización
# 25 Trabajo para una empresa que no tiene oficina en mi ciudad
# 26 Actividad principal
# 27 ¿La recomendás como un buen lugar para trabajar?
# 28 ¿Cómo calificás las políticas de diversidad e inclusión?
# 29 Beneficios extra
# 30 ¿Salir o seguir contestando?
# 31 Nivel de estudios alcanzado
# 32 Estado
# 33 Carrera
# 34 Universidad
# 35 Realizaste cursos de especialización
# 36 ¿Contribuís a proyectos open source?
# 37 ¿Programás como hobbie?
# 38 ¿Salir o seguir contestando?
# 39 ¿Tenés guardias?
# 40 Cuánto cobrás por guardia
# 41 ¿Porcentaje| bruto o neto?
# 42 ¿Salir o seguir contestando?
# 43 ¿Sufriste o presenciaste situaciones de violencia laboral?
# 44 ¿Tenés algún tipo de discapacidad?
# 45 ¿Sentís que esto te dificultó el conseguir trabajo?
# 46 ¿Salir o seguir contestando?
# 47 ¿Cómo venís llevando la pandemia?
# 48 ¿Tenés hijos/as menores de edad?
# 49 ¿Con cuántas personas estás conviviendo?
# 50 ¿Con quiénes convivís?
# 51 ¿Tenés un espacio dedicado para el trabajo?
# 52 ¿Tenés que compartir tu equipo de trabajo con alguien?
# 53 ¿Qué tipo de cuarentena hiciste / estás haciendo?
# 54 ¿Cambió tu situación laboral a raíz de la pandemia?
# 55 ¿Qué tanto sentís que te está apoyando tu empresa/organización en esta situación?
# 56 ¿Cómo se vio afectada tu empresa/organización?
# 57 ¿Instauraron algún beneficio nuevo?
# 58 Tengo
# 59 Me identifico

# %%
for case in raw_cases_ARG:
    dic_cases_list_ARG.append({
            "Pais": "Argentina",
            "Región": case[0],
            "Tipo contrato": case[1] ,
            "Salario Bruto": case[2],
            "Salario Neto" : case[3],
            "Pagos en dólares": case[4],
            "Valor de dólar tomado": case[5],
            "Tipo de Rol": case [13],
            "Años de experiencia": case[14],
            "Años en la empresa actual": case[15],
            "Años en el puesto actual": case[16],
            "Lenguajes de programación": case[19],
            "Nivel de educación formal": case[31],
            "Estado del nivel": case[32],
            "Carrera Universitaria": case[33], #formatearla
            "Cursos de especialización": case[35],
            "Colabora en Open Source": case[36],
            "Programa por hobbie": case[37],
            "Persona con discapacidad": case[44],
            "Edad": case[58],
            "Identidad de Género": case[59]})

print(len(dic_cases_list_ARG))
# Out:
# 6440

# %%
for case in raw_cases_LATAM:
    for i in range (1,19):
        if case[i]:
            region = case[i]
            break
    dic_cases_list_LATAM.append({
            "Pais": case[0],
            "Región": region,
            "Tipo contrato": case[19],
            "Salario Bruto": case[20],
            "Salario Neto" : case[21],
            "Pagos en dólares": case[22],
            "Valor de dólar tomado": case[23],
            "Tipo de Rol": case [31],
            "Años de experiencia": case[32],
            "Años en la empresa actual": case[33],
            "Años en el puesto actual": case[34],
            "Lenguajes de programación": case[37],
            "Nivel de educación formal": case[49],
            "Estado del nivel": case[50],
            "Carrera Universitaria": case[51], #formatearla
            "Cursos de especialización": case[53],
            "Colabora en Open Source": case[54],
            "Programa por hobbie": case[55],
            "Persona con discapacidad": case[62],
            "Edad": case[76],
            "Identidad de Género": case[77]})

print(len(dic_cases_list_LATAM))
# Out:
# 429

# %%
dic_cases_list_ALL = dic_cases_list_LATAM + dic_cases_list_ARG

# %% [markdown]
# 2. Printear porcentaje de participación por región, ordenado de mayor a menor. Ej:
#
# ```
# - Ciudad Autónoma de Buenos Aires - 59.4%
# - Formosa - 0.04%
# ```

# %%
list_keys_regiones = []

for case in dic_cases_list_ALL:
    case_region = case["Región"]
    if case_region not in list_keys_regiones:
        list_keys_regiones.append(case_region)

# %%
dic_regiones = {}

for region in list_keys_regiones:
    dic_regiones[region] = 0
    
dic_regiones
# Out:
# {'Cochabamba': 0,
#  'La Paz': 0,
#  'Santa Cruz de la Sierra': 0,
#  'Santiago': 0,
#  'Maipo': 0,
#  'Biobío': 0,
#  'Valparaíso': 0,
#  'Cachapoal': 0,
#  'Talca': 0,
#  'Valdivia': 0,
#  'Bogotá': 0,
#  'Medellín': 0,
#  'Tunja': 0,
#  'Santiago de Cali': 0,
#  'Cúcuta': 0,
#  'Ibagué': 0,
#  'Cartagena de Indias': 0,
#  'Pereira': 0,
#  'Bucaramanga': 0,
#  'Manizales': 0,
#  'Neiva': 0,
#  'Montería': 0,
#  'Arauca': 0,
#  'Santa Cruz': 0,
#  'San José': 0,
#  'Purral': 0,
#  'Heredia': 0,
#  'Provincia de Ciudad de La Habana': 0,
#  'Sancti Spíritus': 0,
#  'Guayaquil': 0,
#  'Quito': 0,
#  'Salinas': 0,
#  'Cuenca': 0,
#  'Loja': 0,
#  'Ambato': 0,
#  'Riobamba': 0,
#  'Santa Tecla': 0,
#  'San Salvador': 0,
#  'Antigua Guatemala': 0,
#  'Ciudad Guatemala': 0,
#  'San Pedro Sula': 0,
#  'México DF': 0,
#  'Pachuca': 0,
#  'Querétaro': 0,
#  'Cuernavaca': 0,
#  'Monterrey': 0,
#  'Oaxaca de Juárez': 0,
#  'Saltillo': 0,
#  'Guadalajara': 0,
#  'Veracruz': 0,
#  'Villahermosa': 0,
#  'Puebla de Zaragoza': 0,
#  'Chihuahua': 0,
#  'Ecatepec': 0,
#  'Mérida': 0,
#  'Victoria de Durango': 0,
#  'Morelia': 0,
#  'Culiacán': 0,
#  'Zapopan': 0,
#  'Tijuana': 0,
#  'Cancún': 0,
#  'Ciudad Nezahualcóyotl': 0,
#  'Chinandega': 0,
#  'Managua': 0,
#  'Ciudad de Panamá': 0,
#  'San Lorenzo': 0,
#  'Encarnación': 0,
#  'Asunción': 0,
#  'Lima': 0,
#  'Trujillo': 0,
#  'Arequipa': 0,
#  'Puno': 0,
#  'San Juan': 0,
#  'Santo Domingo': 0,
#  'Montevideo': 0,
#  'Maldonado': 0,
#  'Salto': 0,
#  'Trinidad': 0,
#  'Florida': 0,
#  'Barquisimeto': 0,
#  'Caracas': 0,
#  'Valencia': 0,
#  'Barcelona': 0,
#  'San Cristóbal': 0,
#  'Catamarca': 0,
#  'Chaco': 0,
#  'Chubut': 0,
#  'Ciudad Autónoma de Buenos Aires': 0,
#  'Córdoba': 0,
#  'Corrientes': 0,
#  'Entre Ríos': 0,
#  'Formosa': 0,
#  'GBA': 0,
#  'Jujuy': 0,
#  'La Pampa': 0,
#  'La Rioja': 0,
#  'Mendoza': 0,
#  'Misiones': 0,
#  'Neuquén': 0,
#  'Provincia de Buenos Aires': 0,
#  'Río Negro': 0,
#  'Salta': 0,
#  'San Luis': 0,
#  'Santa Fe': 0,
#  'Santiago del Estero': 0,
#  'Tierra del Fuego': 0,
#  'Tucumán': 0}

# %%
for case in dic_cases_list_ALL:
    case_region = case["Región"]
    dic_regiones[case_region] +=1
dic_regiones
# Out:
# {'Cochabamba': 3,
#  'La Paz': 2,
#  'Santa Cruz de la Sierra': 5,
#  'Santiago': 40,
#  'Maipo': 1,
#  'Biobío': 1,
#  'Valparaíso': 3,
#  'Cachapoal': 1,
#  'Talca': 1,
#  'Valdivia': 1,
#  'Bogotá': 19,
#  'Medellín': 17,
#  'Tunja': 3,
#  'Santiago de Cali': 9,
#  'Cúcuta': 1,
#  'Ibagué': 1,
#  'Cartagena de Indias': 1,
#  'Pereira': 2,
#  'Bucaramanga': 1,
#  'Manizales': 3,
#  'Neiva': 1,
#  'Montería': 1,
#  'Arauca': 1,
#  'Santa Cruz': 5,
#  'San José': 3,
#  'Purral': 1,
#  'Heredia': 2,
#  'Provincia de Ciudad de La Habana': 1,
#  'Sancti Spíritus': 1,
#  'Guayaquil': 6,
#  'Quito': 16,
#  'Salinas': 1,
#  'Cuenca': 2,
#  'Loja': 3,
#  'Ambato': 1,
#  'Riobamba': 1,
#  'Santa Tecla': 1,
#  'San Salvador': 1,
#  'Antigua Guatemala': 1,
#  'Ciudad Guatemala': 8,
#  'San Pedro Sula': 1,
#  'México DF': 33,
#  'Pachuca': 2,
#  'Querétaro': 4,
#  'Cuernavaca': 1,
#  'Monterrey': 3,
#  'Oaxaca de Juárez': 2,
#  'Saltillo': 1,
#  'Guadalajara': 7,
#  'Veracruz': 3,
#  'Villahermosa': 2,
#  'Puebla de Zaragoza': 3,
#  'Chihuahua': 1,
#  'Ecatepec': 1,
#  'Mérida': 2,
#  'Victoria de Durango': 1,
#  'Morelia': 2,
#  'Culiacán': 2,
#  'Zapopan': 2,
#  'Tijuana': 1,
#  'Cancún': 1,
#  'Ciudad Nezahualcóyotl': 1,
#  'Chinandega': 1,
#  'Managua': 2,
#  'Ciudad de Panamá': 1,
#  'San Lorenzo': 1,
#  'Encarnación': 1,
#  'Asunción': 6,
#  'Lima': 31,
#  'Trujillo': 1,
#  'Arequipa': 2,
#  'Puno': 1,
#  'San Juan': 24,
#  'Santo Domingo': 1,
#  'Montevideo': 117,
#  'Maldonado': 2,
#  'Salto': 2,
#  'Trinidad': 1,
#  'Florida': 1,
#  'Barquisimeto': 2,
#  'Caracas': 5,
#  'Valencia': 3,
#  'Barcelona': 1,
#  'San Cristóbal': 2,
#  'Catamarca': 3,
#  'Chaco': 39,
#  'Chubut': 19,
#  'Ciudad Autónoma de Buenos Aires': 3552,
#  'Córdoba': 536,
#  'Corrientes': 24,
#  'Entre Ríos': 66,
#  'Formosa': 1,
#  'GBA': 632,
#  'Jujuy': 19,
#  'La Pampa': 8,
#  'La Rioja': 16,
#  'Mendoza': 150,
#  'Misiones': 42,
#  'Neuquén': 47,
#  'Provincia de Buenos Aires': 694,
#  'Río Negro': 52,
#  'Salta': 29,
#  'San Luis': 12,
#  'Santa Fe': 400,
#  'Santiago del Estero': 8,
#  'Tierra del Fuego': 12,
#  'Tucumán': 52}

# %%
sorted_dic_regiones = {}
sorted_regiones_keys = sorted(dic_regiones,key=dic_regiones.get,reverse = True)

for region in sorted_regiones_keys:
    sorted_dic_regiones[region] = dic_regiones[region]
    
sorted_dic_regiones
# Out:
# {'Ciudad Autónoma de Buenos Aires': 3552,
#  'Provincia de Buenos Aires': 694,
#  'GBA': 632,
#  'Córdoba': 536,
#  'Santa Fe': 400,
#  'Mendoza': 150,
#  'Montevideo': 117,
#  'Entre Ríos': 66,
#  'Río Negro': 52,
#  'Tucumán': 52,
#  'Neuquén': 47,
#  'Misiones': 42,
#  'Santiago': 40,
#  'Chaco': 39,
#  'México DF': 33,
#  'Lima': 31,
#  'Salta': 29,
#  'San Juan': 24,
#  'Corrientes': 24,
#  'Bogotá': 19,
#  'Chubut': 19,
#  'Jujuy': 19,
#  'Medellín': 17,
#  'Quito': 16,
#  'La Rioja': 16,
#  'San Luis': 12,
#  'Tierra del Fuego': 12,
#  'Santiago de Cali': 9,
#  'Ciudad Guatemala': 8,
#  'La Pampa': 8,
#  'Santiago del Estero': 8,
#  'Guadalajara': 7,
#  'Guayaquil': 6,
#  'Asunción': 6,
#  'Santa Cruz de la Sierra': 5,
#  'Santa Cruz': 5,
#  'Caracas': 5,
#  'Querétaro': 4,
#  'Cochabamba': 3,
#  'Valparaíso': 3,
#  'Tunja': 3,
#  'Manizales': 3,
#  'San José': 3,
#  'Loja': 3,
#  'Monterrey': 3,
#  'Veracruz': 3,
#  'Puebla de Zaragoza': 3,
#  'Valencia': 3,
#  'Catamarca': 3,
#  'La Paz': 2,
#  'Pereira': 2,
#  'Heredia': 2,
#  'Cuenca': 2,
#  'Pachuca': 2,
#  'Oaxaca de Juárez': 2,
#  'Villahermosa': 2,
#  'Mérida': 2,
#  'Morelia': 2,
#  'Culiacán': 2,
#  'Zapopan': 2,
#  'Managua': 2,
#  'Arequipa': 2,
#  'Maldonado': 2,
#  'Salto': 2,
#  'Barquisimeto': 2,
#  'San Cristóbal': 2,
#  'Maipo': 1,
#  'Biobío': 1,
#  'Cachapoal': 1,
#  'Talca': 1,
#  'Valdivia': 1,
#  'Cúcuta': 1,
#  'Ibagué': 1,
#  'Cartagena de Indias': 1,
#  'Bucaramanga': 1,
#  'Neiva': 1,
#  'Montería': 1,
#  'Arauca': 1,
#  'Purral': 1,
#  'Provincia de Ciudad de La Habana': 1,
#  'Sancti Spíritus': 1,
#  'Salinas': 1,
#  'Ambato': 1,
#  'Riobamba': 1,
#  'Santa Tecla': 1,
#  'San Salvador': 1,
#  'Antigua Guatemala': 1,
#  'San Pedro Sula': 1,
#  'Cuernavaca': 1,
#  'Saltillo': 1,
#  'Chihuahua': 1,
#  'Ecatepec': 1,
#  'Victoria de Durango': 1,
#  'Tijuana': 1,
#  'Cancún': 1,
#  'Ciudad Nezahualcóyotl': 1,
#  'Chinandega': 1,
#  'Ciudad de Panamá': 1,
#  'San Lorenzo': 1,
#  'Encarnación': 1,
#  'Trujillo': 1,
#  'Puno': 1,
#  'Santo Domingo': 1,
#  'Trinidad': 1,
#  'Florida': 1,
#  'Barcelona': 1,
#  'Formosa': 1}

# %%
print("Porcentaje de participacion, sobre el total de respuestas en Total, para cada región (de mayor a menor):")
for region in enumerate(sorted_dic_regiones):
    region_value = round((sorted_dic_regiones[region[1]]/len(dic_cases_list_ALL) * 100),2)
    print(region[1] + " - " + str(region_value) + "%")
# Out:
# Porcentaje de participacion, sobre el total de respuestas en Total, para cada región (de mayor a menor):
# Ciudad Autónoma de Buenos Aires - 51.71%
# Provincia de Buenos Aires - 10.1%
# GBA - 9.2%
# Córdoba - 7.8%
# Santa Fe - 5.82%
# Mendoza - 2.18%
# Montevideo - 1.7%
# Entre Ríos - 0.96%
# Río Negro - 0.76%
# Tucumán - 0.76%
# Neuquén - 0.68%
# Misiones - 0.61%
# Santiago - 0.58%
# Chaco - 0.57%
# México DF - 0.48%
# Lima - 0.45%
# Salta - 0.42%
# San Juan - 0.35%
# Corrientes - 0.35%
# Bogotá - 0.28%
# Chubut - 0.28%
# Jujuy - 0.28%
# Medellín - 0.25%
# Quito - 0.23%
# La Rioja - 0.23%
# San Luis - 0.17%
# Tierra del Fuego - 0.17%
# Santiago de Cali - 0.13%
# Ciudad Guatemala - 0.12%
# La Pampa - 0.12%
# Santiago del Estero - 0.12%
# Guadalajara - 0.1%
# Guayaquil - 0.09%
# Asunción - 0.09%
# Santa Cruz de la Sierra - 0.07%
# Santa Cruz - 0.07%
# Caracas - 0.07%
# Querétaro - 0.06%
# Cochabamba - 0.04%
# Valparaíso - 0.04%
# Tunja - 0.04%
# Manizales - 0.04%
# San José - 0.04%
# Loja - 0.04%
# Monterrey - 0.04%
# Veracruz - 0.04%
# Puebla de Zaragoza - 0.04%
# Valencia - 0.04%
# Catamarca - 0.04%
# La Paz - 0.03%
# Pereira - 0.03%
# Heredia - 0.03%
# Cuenca - 0.03%
# Pachuca - 0.03%
# Oaxaca de Juárez - 0.03%
# Villahermosa - 0.03%
# Mérida - 0.03%
# Morelia - 0.03%
# Culiacán - 0.03%
# Zapopan - 0.03%
# Managua - 0.03%
# Arequipa - 0.03%
# Maldonado - 0.03%
# Salto - 0.03%
# Barquisimeto - 0.03%
# San Cristóbal - 0.03%
# Maipo - 0.01%
# Biobío - 0.01%
# Cachapoal - 0.01%
# Talca - 0.01%
# Valdivia - 0.01%
# Cúcuta - 0.01%
# Ibagué - 0.01%
# Cartagena de Indias - 0.01%
# Bucaramanga - 0.01%
# Neiva - 0.01%
# Montería - 0.01%
# Arauca - 0.01%
# Purral - 0.01%
# Provincia de Ciudad de La Habana - 0.01%
# Sancti Spíritus - 0.01%
# Salinas - 0.01%
# Ambato - 0.01%
# Riobamba - 0.01%
# Santa Tecla - 0.01%
# San Salvador - 0.01%
# Antigua Guatemala - 0.01%
# San Pedro Sula - 0.01%
# Cuernavaca - 0.01%
# Saltillo - 0.01%
# Chihuahua - 0.01%
# Ecatepec - 0.01%
# Victoria de Durango - 0.01%
# Tijuana - 0.01%
# Cancún - 0.01%
# Ciudad Nezahualcóyotl - 0.01%
# Chinandega - 0.01%
# Ciudad de Panamá - 0.01%
# San Lorenzo - 0.01%
# Encarnación - 0.01%
# Trujillo - 0.01%
# Puno - 0.01%
# Santo Domingo - 0.01%
# Trinidad - 0.01%
# Florida - 0.01%
# Barcelona - 0.01%
# Formosa - 0.01%

# %% [markdown]
# 3. Printear porcentaje de participación por tipo de rol, ordenado de mayor a menor. Ej:
# `- Developer - 39.11 %`

# %%
list_keys_roles = []

for case in dic_cases_list_ALL:
    case_rol = case["Tipo de Rol"]
    if case_rol not in list_keys_roles:
        list_keys_roles.append(case_rol)

# %%
dic_roles = {}

for rol in list_keys_roles:
    dic_roles[rol] = 0

# %%
for case in dic_cases_list_ALL:
    case_rol = case["Tipo de Rol"]
    dic_roles[case_rol] +=1

# %%
sorted_dic_roles = {}
sorted_roles_keys = sorted(dic_roles, key=dic_roles.get)

for rol in sorted_roles_keys:
    sorted_dic_roles[rol] = dic_roles[rol]

# %%
print("Porcentaje de participacion, sobre el total de respuestas, para cada Tipo de Rol (de menor a mayor):")
for rol in enumerate(sorted_dic_roles):
    rol_value = round((sorted_dic_roles[rol[1]]/len(dic_cases_list_ALL) * 100),2)
    print(rol[1] + " - " + str(rol_value) + "%")
# Out:
# Porcentaje de participacion, sobre el total de respuestas, para cada Tipo de Rol (de menor a mayor):
# Alliances Manager (Indirect Sales) - 0.01%
# Data Quality - 0.01%
# Aprentice - 0.01%
# ingeniero infraestructuras de virtualizacion - 0.01%
# Teacher - 0.01%
# Profesor de teatro  - 0.01%
# TI - 0.01%
# Mix entre SysAdmin y Developer pasando por DBA - 0.01%
# Chef - 0.01%
# Artesanal - 0.01%
# Technical Support Engineer - 0.01%
# Salesforce Admin/Developer - 0.01%
# Analista Funcional de Sistemas - 0.01%
# independiente  - 0.01%
# Soporte on site - 0.01%
# App analyst - 0.01%
# Cajera - 0.01%
# Technical Business Analyst - 0.01%
# Administrador Infraestructura - 0.01%
# help desk + backup + vmware + sys admin - 0.01%
# Data Visualization - 0.01%
# Mainframe - 0.01%
# machine learning egineer - 0.01%
# exploit writer - 0.01%
# BI Sr. Manager - 0.01%
# Operador - 0.01%
# soporte nivel 1|2 y 3 - 0.01%
#  Cloud Architect - 0.01%
# Engineering Manager - 0.01%
# Técnicamente soy QA pero hago trabajo de PO ¿trainee? - 0.01%
# SRE - 0.01%
# supervisor helpdek - 0.01%
# Asistencia técnica - 0.01%
# lead - 0.01%
# Soporte - 0.01%
# Tech support  - 0.01%
# Back office - 0.01%
# analista - 0.01%
# Jefe operacion ti - 0.01%
# Auditoría - 0.01%
# IT Infrastructure Engineer - 0.01%
# Data Center - 0.01%
# Software engineer  - 0.01%
# Information Security - 0.01%
# SAP Basis - 0.01%
# Seguridad informática  - 0.01%
# Seguridad - 0.01%
# Coordinador operaciones y soporte aplicativo - 0.01%
# Application Engineer - 0.01%
# Becario doctoral  - 0.01%
# Automation Engineer - 0.01%
# Analista Tecnico - 0.01%
# Frontend Developer - 0.01%
# Jefe de Sistemas - 0.01%
# IT Auditor - 0.01%
# Security Architect - 0.01%
# implementacion de sistemas informatico de salud -SAP -Funcional - 0.01%
# Gerente de Sistemas - 0.01%
# soporte  técnico nivel 3 (infraestructura) - 0.01%
# Seguridad informatica - 0.01%
# Comunicación / Redes sociales - 0.01%
# adm de infra - 0.01%
# Developer| DevOps - 0.01%
# Analista SAP Basis - 0.01%
# Soporte Tecnico SQL - 0.01%
# QA Automation  - 0.01%
# team leader - 0.01%
# AV Technical Support - 0.01%
# Sales Executive - 0.01%
# ETL DEVELOPER - 0.01%
# Security researcher - 0.01%
# Gerente de atracción de TI y Comercial - 0.01%
# Cybersecurity  - 0.01%
# Delivery Manager - 0.01%
# Varios - 0.01%
# Integration  - 0.01%
# Problem Manager - 0.01%
# Soporte IT LAB nivel 1| 2| 3  - 0.01%
# Director of DevOps and IT - 0.01%
# Proyect Leader / Developer / Toolsmith - 0.01%
# Technical Owner - 0.01%
# Datasteward - 0.01%
# Seguridad Informática - Accesos - 0.01%
# IPM - 0.01%
# Esp. Telecomunicaciones - 0.01%
# Agile coach - 0.01%
# QA - Automation Engineer - 0.01%
# Ad Tech - 0.01%
# Trainee etl - 0.01%
# Data Governance Specialist - 0.01%
# Jefe de canales digitales - 0.01%
# Ingeniero en Seguridad Informatica - 0.01%
# Incident&Risk Leader - 0.01%
# Machine Learning Engineer - 0.01%
# Developer/DevOps - 0.01%
# UX User Research - 0.01%
# UX Leader - 0.01%
# IT Operations Analyst - 0.01%
# Customer success manager - 0.01%
# Marketing - 0.01%
# Analista mainframe - 0.01%
# Application DBA - 0.01%
# Network Analyst Security - 0.01%
# uxui - 0.01%
# CyberSecurity - 0.01%
# Tech Lead / Arquitecto - 0.01%
# Consultor Senior - Especialista en Ciberseguridad - 0.01%
# Qa lead - 0.01%
# Service Delivery Manager| Application Support| ITGC - 0.01%
# Administrador de Windows Server - Cloud - 0.01%
# Analista contable  - 0.01%
# Servicio técnico  - 0.01%
# Functional Analyst Jr - 0.01%
# Operation Lead - 0.01%
# Cloud Admin - 0.01%
# Technical Support - 0.01%
# Analista IT - 0.01%
# Integration Developer - 0.01%
# Profesor de Tecnología de la Información - 0.01%
# AppDynamics Engineer - 0.01%
# Research - 0.01%
# Functional - 0.01%
# Technical Account Manager - 0.01%
# Analista de sistema - 0.01%
# Ingeniero de Laboratorio - 0.01%
# Gerente - 0.01%
# Atlassian Specialist - 0.01%
# RPA & ETL Developer - 0.01%
# mezcla de sysadmin| networking| dba... de todo un poco - 0.01%
# FULL STACK Y BI - 0.01%
# NLP Analyst - 0.01%
# devops - 0.01%
# Analista de metodología - 0.01%
# Computational Linguist Junior - 0.01%
# Analista NPL - 0.01%
# Consultor de Implementación - 0.01%
# NOC - 0.01%
# analista de sistemas - 0.01%
# Trafficker - 0.01%
# Calidad - 0.01%
# RRHH - 0.01%
# Creative Copywriter - 0.01%
# Pipeline Technical Artist - 0.01%
# Desarrollador plsql + Desarrollador web + soporte-analista funcional - 0.01%
# Analista Seguridad informatica - 0.01%
# Sr Staff engineer - 0.01%
# Tech Manager - 0.01%
# Analista funcional sr - 0.01%
# Jefe de it - 0.01%
# Ingeniero de soporte - 0.01%
# Gerente de Atracción de talentos y comercial - 0.01%
# Product designer - 0.01%
# Senior Product Owner - 0.01%
# Product support - 0.01%
# Cloud Engineer - 0.01%
# Ingeniero en informatica - 0.01%
# Responsable de Marketing - 0.01%
# Data Modeling Engineer - 0.01%
# CTO - 0.01%
# Cloud admin - 0.01%
# analisis funcional - 0.01%
# Media comunnications - 0.01%
# Analyst - 0.01%
# UI  - 0.01%
# Jefe de Soporte y Operaciones - 0.01%
# Soy el dpto de sistemas en una escuela de 80 pc y 400 por wifi..hago todo - 0.01%
# Software engineer - 0.01%
# Cyber security - 0.01%
# Analytics Engineer - 0.01%
# conversational designer - 0.01%
# administrativo - 0.01%
# Access Managment Sr - 0.01%
# Sistemas - 0.01%
# Productora de Eventos - 0.01%
# IT Specialist - 0.01%
# Product Analyst - 0.01%
# Soporte técnico - 0.01%
# Support Senior - 0.01%
# Soporte Transaccional - 0.01%
# suport L2 - 0.01%
# ERP Developer - 0.01%
# RPA DEVELOPER - 0.01%
# Test Automation Engineer - 0.01%
# Field Operations / Telecommunications - 0.01%
# Research Engineer - 0.01%
# Responsable de área de sistemas  - 0.01%
# Soporte Nivel 2 - 0.01%
# Encargado Área de Sistemas - 0.01%
# Atlassian Consultant - 0.01%
# Business Analyst y Scrum Master - 0.01%
# Noc  - 0.01%
# full stack developer - 0.01%
# SupportEngineer - 0.01%
# QA Lead - 0.01%
# Docencia - 0.01%
# CloudEngineer/Dev/DevOps - 0.01%
# artist - 0.01%
# Product Lead - 0.01%
# Team Lead - 0.01%
# Project Manager| Product Manager| Developer| SRE - 0.01%
# Tecnico telecomunicaciones - 0.01%
# Laboratorio universitario - 0.01%
# Administrativo  - 0.01%
# SITE SUPPORT - 0.01%
# soporte técnico - 0.01%
# Wordpress - 0.01%
# Cloud - 0.01%
# IT Services - 0.01%
# Lead Data Engineer - 0.01%
# Project Leader - 0.01%
# ADMINISTRATIVA - 0.01%
# CRO - 0.01%
# Trainee - 0.01%
# Security Engineer - 0.01%
# Operador NOC - 0.01%
# jefe de sistemas - 0.01%
# tecnico de calle - 0.01%
# redactor y editor| diseño| contenidos - 0.01%
# Product Security - 0.01%
# On Site Support - 0.01%
# SAP Basis administrator - 0.01%
# CRM developer - 0.01%
# Integrator - 0.01%
# Operador noc - 0.01%
# Administrativa  - 0.01%
# Soporte Tecnico de Infraestructura - 0.01%
# ADMINISTRATIVO DE DEPOSITO - 0.01%
# Postproducer - 0.01%
# DevOps| Desarrollo| Diseño| Instalo arquitectura| Monitoreo| etc - 0.01%
# Systems integration analyst - 0.01%
# People Care - 0.01%
# Docente Universitario - 0.01%
# Helpdesl / Tecnico en Reparacion de PC| Notebooks e impresoras / Tecnico instalador de HFC y FTTH - 0.01%
# Security Analist - 0.01%
# De todo un poco - 0.01%
# Fullstack - 0.01%
# soporte tecnico - 0.01%
# Especialista en Yacimiento Digital - 0.01%
# mezcla entre helpdesk y admin base de datos - 0.01%
# Productivity & collaboration - 0.01%
# DBA / Developer - 0.01%
# Ayudante en cursos de programación - 0.01%
# Administrador de sistema ERP - 0.01%
# Growth Engineer  - 0.01%
# Programador - 0.01%
# Tecnology - 0.01%
# Cloud engineer - 0.01%
# Jefe división Informática - 0.01%
# subject matter expert - 0.01%
# BI Engineer - 0.01%
# de todo - 0.01%
# Analista funcional  - 0.01%
# Digital Marketing - 0.01%
# Analista funcional y coordinadora de grupo de mantenimiento  - 0.01%
# TI-Infraestructura - 0.01%
# Security Research - 0.01%
# Support - 0.01%
# Responsable it - 0.01%
# Profesor de Informática - 0.01%
# FrontEnd Chapter Lead - 0.01%
# software ingeniero - 0.01%
# Tutor - 0.01%
# Technical support (not help desk) - 0.01%
# Principal SE - 0.01%
# BI Developer - 0.01%
# Architecture engineering  - 0.01%
# PMO Manager - 0.01%
# Instructor - 0.01%
# Chapter Lead - 0.01%
# Programador de automatas - 0.01%
# Responsable de Infraestructura - 0.01%
# Deposito - 0.01%
# UI - frontend - 0.01%
# CIO - 0.01%
# Cashier - 0.01%
# Operations Lead - 0.01%
# Freelance - 0.01%
# Application Support - 0.01%
# DBA+frontend - 0.01%
# Education - 0.01%
# IT Support - 0.01%
# Business Analyst| QA / Tester| Project Manager|Product Manager - 0.01%
# Referente de area  - 0.01%
# Desarrollos de modelos fisicos en C| C++ o Python| para ser integrados en un software de simulacion de vuelo - 0.01%
# administracion - 0.01%
# Redacción - 0.01%
# tecnico - 0.01%
# Administración - 0.01%
# redactor creativo - 0.01%
# Telecomunicaciones  - 0.01%
# Desarrollador ETL - 0.01%
# Analista implementador - 0.01%
# Jefe de Área de Sistemas - 0.01%
# Estructurado - 0.01%
# RPA Developer - 0.01%
# Soporte de Campo - 0.01%
# Implementador de sistemas - 0.01%
# Auditoria - 0.01%
# Ingeniero Electrónico - 0.01%
# Implementador de Sistemas - 0.01%
# Administrativo - 0.01%
# Implementador - 0.01%
# SysAdmin / Storage / Backup / Networking - 0.01%
# Community manager en IT - 0.01%
# TI generalista - 0.01%
# FrontEnd Developer - 0.01%
# Atención al cliente en Naranja X - 0.01%
# Analista - 0.03%
# Team leader - 0.03%
# Support Engineer - 0.03%
# People Analytics - 0.03%
# Data Architect - 0.03%
# Team Leader - 0.03%
# Productor y vendedor - 0.03%
# Cloud Security - 0.03%
# NLP Developer - 0.03%
# Soporte tecnico - 0.03%
# SDET - 0.03%
# Profesor - 0.03%
# Cybersecurity - 0.03%
# Functional Analyst - 0.03%
# Product owner - 0.03%
# Technical Analyst - 0.03%
# Service Designer - 0.03%
# Project Engineering - 0.03%
# Auditor - 0.03%
# QA Automation - 0.03%
# Functional analyst - 0.03%
# UI - 0.03%
# Soporte IT - 0.03%
# Change Manager - 0.03%
# soporte - 0.03%
# Agile Coach - 0.04%
# Software Engineer - 0.04%
# analista funcional - 0.04%
# Analista Funcional - 0.04%
# DevOps - 0.04%
# Coordinador - 0.04%
# RPA - 0.04%
# Product Owner - 0.06%
# Docente - 0.07%
# Analista funcional - 0.09%
# Storage / Backup - 0.12%
# Technical Writer - 0.16%
# Middleware - 0.17%
# Finance - 0.17%
# Sales / Pre-Sales - 0.42%
# VP / C-Level - 0.55%
# Designer - 0.64%
# Scrum Master - 0.66%
# DBA - 0.71%
# Product Manager - 1.21%
# Recruiter / HR - 1.24%
# Infosec - 1.43%
# Data Scientist - 1.48%
# UX - 1.5%
# Networking - 1.54%
# Business Analyst - 1.69%
# Data Engineer - 1.76%
# Consultant - 1.92%
# Architect - 2.23%
# BI Analyst / Data Analyst - 2.45%
# HelpDesk - 2.62%
# Project Manager - 3.09%
# Manager / Director - 4.28%
# QA / Tester - 4.29%
# Technical Leader - 6.16%
# SysAdmin / DevOps / SRE - 11.09%
# Developer - 40.69%

# %% [markdown]
# 4. Printear porcentaje de respuesta para las preguntas:
# * ¿Contribuís a proyectos Open Source?
# * ¿Programás por hobbie?

# %%
result_os_si = []
result_os_no = []

for case in dic_cases_list_ALL:
    case_os = case["Colabora en Open Source"]
    if case_os == "No":
        result_os_no.append(case_os)
    if case_os == "Sí":
        result_os_si.append(case_os)
    
q_respuestas_si = len(result_os_si)
q_respuestas_no = len(result_os_no)

total_respuestas_os = q_respuestas_si + q_respuestas_no

per_respuestas_si = round((q_respuestas_si/total_respuestas_os * 100),2)

print("El total de personas que colaboran en proyectos Open Source, sobre el total de personas que respondieron a la pregunta, es " + str(per_respuestas_si) + "%")
# Out:
# El total de personas que colaboran en proyectos Open Source, sobre el total de personas que respondieron a la pregunta, es 14.97%

# %%
result_hobbie_si = []
result_hobbie_no = []

for case in dic_cases_list_ALL:
    case_hobbie = case["Programa por hobbie"]
    if case_hobbie == "No":
        result_hobbie_no.append(case_hobbie)
    if case_hobbie == "Sí":
        result_hobbie_si.append(case_hobbie)
    
q_respuestas_si = len(result_hobbie_si)
q_respuestas_no = len(result_hobbie_no)

total_respuestas_hobbie = q_respuestas_si + q_respuestas_no

per_respuestas_si = round((q_respuestas_si/total_respuestas_hobbie * 100),2)

print("El total de personas que programan por Hobbie, sobre el total de personas que respondieron a la pregunta, es " + str(per_respuestas_si) + "%")
# Out:
# El total de personas que programan por Hobbie, sobre el total de personas que respondieron a la pregunta, es 56.06%

# %% [markdown]
# 5. Printear porcentaje por seniority según años de experiencia, el mapeo es:
# ```
# Junior: de 0 hasta 2 años.
# Semi-Senior: de 2 años inclusive hasta 5 años.
# Senior: desde 5 años inclusive.
# ```

# %% [markdown]
# 6. Printear porcentaje de personas encuestadas por años en la compañía actual y por años en el puesto actual.

# %%
#armar rangos de Años dependiendo lo que te trae ese campo

# %% [markdown]
# 7. Printear porcentajes de nivel de educación formal y estado, es decir: % educación secundaria, terciaria, universitaria, postgrado, doctorado, postdoctorado, completo, incompleto y en curso para cada uno.

# %% [markdown]
# 8. Formatear las carreras universitarias:
# - Nombres capitalizados
# - Reemplazar vocales con tilde por vocales sin tilde.
# - Reemplazar `ñ` por `n`
# - *lic*, *lic.* por Licenciatura
# - *tec*, *tec.* por Tecnucatura
# * *cs, *cs.* por Ciencias
# * *ed, ed.* por Educación
# * Transformaciones que se consideren necesarias
#
# Printear porcentaje según carrera

# %% [markdown]
# 9. Printear porcentaje de respuesta a las preguntas:
# - ¿Realizaste cursos de especialización?
# - Si realizaste, ¿Quién pagó por los cursos de especialización?

# %%
list_keys_esp = []

for case in dic_cases_list_ALL:
    case_esp = case["Cursos de especialización"]
    if case_esp not in list_keys_esp:
        list_keys_esp.append(case_esp)

list_keys_esp
# Out:
# ['Sí| los pagó un empleador',
#  '',
#  'Sí| de forma particular',
#  'Sí| de forma particular| Sí| los pagó un empleador',
#  'No',
#  'No| Sí| los pagó un empleador',
#  'No| Sí| de forma particular']

# %%
result_esp_particular = []
result_esp_empleador = []
result_esp_no = []

for case in dic_cases_list_ALL:
    case_esp = case["Cursos de especialización"]
    if case_esp == "No":
        result_esp_no.append(case_esp)
    if "particular" in case_esp:
        result_esp_particular.append(case_esp)
    if  "empleador" in case_esp:
        result_esp_empleador.append(case_esp)

q_respuestas_particular = len(result_esp_particular)
q_respuestas_empleador = len(result_esp_empleador)          
q_respuestas_si = q_respuestas_particular + q_respuestas_empleador
q_respuestas_no = len(result_esp_no)

total_respuestas_esp = q_respuestas_particular + q_respuestas_empleador + q_respuestas_no
per_respuestas_si = round((q_respuestas_si/total_respuestas_esp * 100),2)

per_respuestas_particular = round((q_respuestas_particular/total_respuestas_esp * 100),2)
per_respuestas_empleador = round((q_respuestas_empleador/total_respuestas_esp * 100),2)

print("El porcentaje de personas que realizaron cursos de especialización, sobre el total de personas que respondieron a la pregunta, es " + str(per_respuestas_si) + "%")

print("Del total de personas que realizaron cursos de especialización, el " + str(per_respuestas_particular) + "% lo pagó particular y el " + str(per_respuestas_empleador) + "% lo pagó el empleador")
# Out:
# El porcentaje de personas que realizaron cursos de especialización, sobre el total de personas que respondieron a la pregunta, es 82.67%
# Del total de personas que realizaron cursos de especialización, el 58.58% lo pagó particular y el 24.09% lo pagó el empleador

# %% [markdown]
# 10. Printear porcentaje por identidad de género y personas con discapacidad

# %% [markdown]
# 11. Salarios: calcular la mediana salarial para cada una de las siguientes categorías:
# - Salario según región
# - Salario por rol
# - Salario por experiencia
# - Salario por nivel de formación
# - Salario por carrera
# - Salario por tecnología
# - Salario por lenguaje de programación
# - Salario por género

# %% [markdown]
# 12. Printear porcentaje y salario según tipos de contrato .
